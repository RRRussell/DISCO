# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd

from torch.utils.data import Dataset, DataLoader

from data import load_test_data, generate_training_samples
from dataset import STDataset
from baseline import GANBaseline
from evaluate import Evaluator
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
all_test_items = load_test_data(num_holes=10)
# Out:
# Seeding all randomness with seed=2024
# Donor_id: MsBrainAgingSpatialDonor_1
# Slice_id: 0
# Donor_id: MsBrainAgingSpatialDonor_2
# Slice_id: 0
# Slice_id: 1
# Donor_id: MsBrainAgingSpatialDonor_3
# Slice_id: 0
# Slice_id: 1
# Donor_id: MsBrainAgingSpatialDonor_4
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_5
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_6
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_7
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_8
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_9
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_10
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_11
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_12
# Slice_id: 0
# Slice_id: 1

# %%
training_samples = generate_training_samples(num_samples_per_slice=10)
# Out:
# Seeding all randomness with seed=2024

# %%
training_samples
# Out:
# [{'normalized_positions': array([[0.56965703, 0.14636786],
#          [0.77828302, 0.12849187],
#          [0.50011503, 0.45695788],
#          [0.71833302, 0.07028587],
#          [0.45542503, 0.85175587],
#          [0.35978301, 0.06723387],
#          [0.73206702, 0.82385187],
#          [0.34168901, 0.69283387],
#          [0.24402502, 0.63179387],
#          [0.98843502, 0.49161988],
#          [0.79790302, 0.69741187],
#          [0.20870902, 0.04390787],
#          [0.28152101, 0.30937188],
#          [0.31552901, 0.32179788],
#          [0.23203502, 0.31373188],
#          [0.00989302, 0.35951188],
#          [0.30484701, 0.01098987],
#          [0.89796502, 0.11105187],
#          [0.73250302, 0.34904788],
#          [0.65358702, 0.13437787],
#          [0.24511502, 0.55549387],
#          [0.37744101, 0.10124187],
#          [0.46567103, 0.03213587],
#          [0.46545303, 0.18386386],
#          [0.25012902, 0.48180988],
#          [0.89774702, 0.30021588],
#          [0.62720903, 0.89034187],
#          [0.81970302, 0.52933387],
#          [0.59712503, 0.13590387],
#          [0.46959503, 0.97318186],
#          [0.43608301, 0.15726786],
#          [0.85763502, 0.47744988],
#          [0.16271102, 0.05916787],
#          [0.03409102, 0.42033388],
#          [0.12412502, 0.00205187],
#          [0.00771302, 0.30784588],
#          [0.31967101, 0.52606387],
#          [0.83845102, 0.24294186],
#          [0.42278501, 0.25275186],
#          [0.24402502, 0.00989987],
#          [0.88662902, 0.07290187],
#          [0.87442102, 0.72269987],
#          [0.29939701, 0.43188788],
#          [0.62699103, 0.60018387],
#          [0.75800902, 0.76215787],
#          [0.37962101, 0.52824387],
#          [0.89207902, 0.40834388],
#          [0.49619103, 0.77349387],
#          [0.46567103, 0.23269586],
#          [0.52562103, 0.38240188]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  2.203905  ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                3.697623  , -0.15858787],
#              ...,
#              [ 3.254573  , -0.43280727,  2.7005317 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  2.5918953 , ...,  2.1076381 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 0.94}},
#  {'normalized_positions': array([[0.97798274, 0.68338126],
#          [0.39598273, 0.41720327],
#          [0.76135073, 0.0760935 ],
#          [0.90414072, 0.82442726],
#          [0.37309274, 0.82290126],
#          [0.78206073, 0.57830526],
#          [0.28720074, 0.32760527],
#          [0.56427873, 0.1798615 ],
#          [0.19439272, 0.44619727],
#          [0.42781073, 0.34003127],
#          [0.97782472, 0.37861727],
#          [0.79841073, 0.36924327],
#          [0.34933074, 0.0719515 ],
#          [0.47119273, 0.95086725],
#          [0.66281473, 0.0883015 ],
#          [0.48645273, 0.54080926],
#          [0.74064073, 0.66136326],
#          [0.59305473, 0.52206126],
#          [0.96452672, 0.29431149],
#          [0.12790272, 0.2167035 ],
#          [0.60918673, 0.28253949],
#          [0.16141474, 0.45905927],
#          [0.70445273, 0.1667815 ],
#          [0.99520474, 0.60664526],
#          [0.23204674, 0.2753455 ],
#          [0.80168073, 0.1449815 ],
#          [0.34911274, 0.88263326],
#          [0.62248473, 0.1414935 ],
#          [0.10653872, 0.84012326],
#          [0.89520272, 0.1159875 ],
#          [0.90217872, 0.72305726],
#          [0.40077873, 0.57765126],
#          [0.72516273, 0.67531526],
#          [0.47446273, 0.82311926],
#          [0.95493472, 0.53535926],
#          [0.62967873, 0.76360526],
#          [0.78838273, 0.77450526],
#          [0.93896074, 0.2341435 ],
#          [0.25232074, 0.77297926],
#          [0.33341674, 0.96721725],
#          [0.74870673, 0.2740375 ],
#          [0.23291874, 0.85233126],
#          [0.14070474, 0.0501515 ],
#          [0.07798072, 0.56914926],
#          [0.40666473, 0.92187325],
#          [0.40906273, 0.68141926],
#          [0.34388074, 0.0246455 ],
#          [0.17929074, 0.68512526],
#          [0.56449673, 0.44990327],
#          [0.51370273, 0.71193926]]),
#   'gene_expressions': ArrayView([[ 2.1696386 , -0.43280727, -0.43380988, ...,  1.1220145 ,
#                2.169607  ,  5.2720613 ],
#              [-0.3077751 , -0.43280727,  0.73463213, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  0.94322103,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                1.8772324 ,  4.6350226 ],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.93910738, 0.34399648],
#          [0.42054537, 0.65137647],
#          [0.03337738, 0.15172048],
#          [0.93256738, 0.98943448],
#          [0.60388337, 0.24110048],
#          [0.03490338, 0.44711047],
#          [0.80263938, 0.02266448],
#          [0.86782138, 0.60407047],
#          [0.99796738, 0.18703648],
#          [0.48921537, 0.33418648],
#          [0.74726739, 0.93755048],
#          [0.65184337, 0.87825448],
#          [0.20341738, 0.86539248],
#          [0.94760938, 0.28644448],
#          [0.93082338, 0.45757447],
#          [0.89768738, 0.20731048],
#          [0.84231538, 0.12468848],
#          [0.06455138, 0.85253048],
#          [0.08613338, 0.00348048],
#          [0.85735738, 0.66423847],
#          [0.55679537, 0.66729047],
#          [0.97006338, 0.93384448],
#          [0.79370138, 0.15302848],
#          [0.72138537, 0.80151848],
#          [0.71724337, 0.86081448],
#          [0.75097339, 0.63044847],
#          [0.01135938, 0.52253847],
#          [0.40027138, 0.68865447],
#          [0.54807537, 0.84402848],
#          [0.11403738, 0.17897048],
#          [0.89659738, 0.15477248],
#          [0.92886138, 0.73655449],
#          [0.82269538, 0.51185647],
#          [0.33421738, 0.83094848],
#          [0.84493138, 0.38955847],
#          [0.03468538, 0.74462048],
#          [0.03577538, 0.41484647],
#          [0.89289138, 0.71584449],
#          [0.16897338, 0.06539248],
#          [0.16722938, 0.38149247],
#          [0.51036137, 0.51185647],
#          [0.41662137, 0.53997847],
#          [0.40419538, 0.34443248],
#          [0.93867138, 0.01743248],
#          [0.73484139, 0.39195647],
#          [0.36233938, 0.29494648],
#          [0.67451537, 0.94997648],
#          [0.87087338, 0.93471648],
#          [0.06346138, 0.65050447],
#          [0.53041737, 0.12643248]]),
#   'gene_expressions': ArrayView([[ 1.7860049 ,  1.0142385 , -0.43380988, ..., -0.53142697,
#               -0.32283673,  4.4311113 ],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  1.6024195 ,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  0.6912326 , -0.43380988, ..., -0.53142697,
#                1.3134421 , -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  0.89869773,
#                1.8329731 ,  4.538588  ]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer V',
#    'tissue_percentage': 0.9}},
#  {'normalized_positions': array([[0.15268948, 0.94202218],
#          [0.20195748, 0.11150218],
#          [0.70787549, 0.49496417],
#          [0.88554548, 0.92785218],
#          [0.64574549, 0.22551617],
#          [0.57206149, 0.54772017],
#          [0.39809749, 0.00315618],
#          [0.93568548, 0.29178817],
#          [0.90908948, 0.96447618],
#          [0.20348348, 0.19892017],
#          [0.38267948, 0.49169417],
#          [0.96184548, 0.21941217],
#          [0.97732348, 0.20546017],
#          [0.76477349, 0.77089218],
#          [0.21874348, 0.66320018],
#          [0.47483349, 0.44504217],
#          [0.20064948, 0.93875218],
#          [0.75038549, 0.25603617],
#          [0.83409748, 0.80490018],
#          [0.53478349, 0.75846618],
#          [0.71223549, 0.75541418],
#          [0.74406349, 0.44090017],
#          [0.58579549, 0.42673017],
#          [0.28566948, 0.69045018],
#          [0.99868748, 0.90997618],
#          [0.04434348, 0.38661817],
#          [0.34670948, 0.70767218],
#          [0.80793748, 0.56646817],
#          [0.90494748, 0.47796017],
#          [0.08292948, 0.13962418],
#          [0.51232949, 0.56799417],
#          [0.33907948, 0.18932817],
#          [0.43711949, 0.73797418],
#          [0.87486348, 0.38029617],
#          [0.60977549, 0.36699817],
#          [0.66383949, 0.50782617],
#          [0.69697549, 0.59502616],
#          [0.99432748, 0.63442418],
#          [0.22266748, 0.54554017],
#          [0.45412349, 0.89798618],
#          [0.17230948, 0.63050018],
#          [0.53478349, 0.90954018],
#          [0.63549949, 0.54706617],
#          [0.93873748, 0.79552618],
#          [0.15661348, 0.82495618],
#          [0.51974149, 0.16404018],
#          [0.64334749, 0.46597017],
#          [0.31466348, 0.11324618],
#          [0.23509348, 0.88599618],
#          [0.38872349, 0.89755018]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 1.4266704 ,  1.489461  , -0.43380988, ...,  0.6261528 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  2.183992  ,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                2.3725576 , -0.15858787],
#              [-0.3077751 , -0.43280727,  0.43331158, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.6263466 ,  1.5950124 , -0.43380988, ...,  2.9462986 ,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.85307477, 0.66306895],
#          [0.74451077, 0.20788496],
#          [0.69262677, 0.85294695],
#          [0.35129876, 0.54665696],
#          [0.86135877, 0.04815095],
#          [0.50078678, 0.52812696],
#          [0.90953677, 0.56453296],
#          [0.11040877, 0.13681697],
#          [0.41620278, 0.17038897],
#          [0.72489077, 0.46556096],
#          [0.72292877, 0.51962496],
#          [0.37412878, 0.72280095],
#          [0.20175077, 0.27284896],
#          [0.93242677, 0.07867095],
#          [0.60259278, 0.02220895],
#          [0.27565276, 0.98085272],
#          [0.37920276, 0.93251695],
#          [0.37048276, 0.79910095],
#          [0.12654077, 0.64780895],
#          [0.69240877, 0.90003495],
#          [0.26257276, 0.55036296],
#          [0.13722277, 0.86951495],
#          [0.60346478, 0.50327496],
#          [0.01100077, 0.91392672],
#          [0.52847278, 0.05251095],
#          [0.54874678, 0.44354296],
#          [0.29243876, 0.80629495],
#          [0.96926877, 0.96450272],
#          [0.96142077, 0.19044497],
#          [0.27085676, 0.66917295],
#          [0.67693077, 0.93774895],
#          [0.23248876, 0.07278495],
#          [0.97951477, 0.56213496],
#          [0.20698277, 0.70732295],
#          [0.03062077, 0.71342695],
#          [0.85939677, 0.60377296],
#          [0.53348678, 0.19371497],
#          [0.57054678, 0.69576895],
#          [0.27020276, 0.21834896],
#          [0.25559676, 0.77250495],
#          [0.42062276, 0.04139295],
#          [0.54831078, 0.37443696],
#          [0.83999477, 0.26303896],
#          [0.81492477, 0.83637895],
#          [0.18104077, 0.95475295],
#          [0.26518876, 0.30271496],
#          [0.66079877, 0.32277096],
#          [0.15052077, 0.50371096],
#          [0.97777077, 0.88324895],
#          [0.47746078, 0.44419696]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                2.7474136 , -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 3.4144886 , -0.43280727, -0.43380988, ...,  1.9528351 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  0.9341266 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.58687344, 0.23783662],
#          [0.57706344, 0.12316862],
#          [0.33181345, 0.23369462],
#          [0.62654944, 0.66462063],
#          [0.10269545, 0.59513861],
#          [0.40200944, 0.43948662],
#          [0.03081543, 0.31849662],
#          [0.03757343, 0.16829462],
#          [0.70568344, 0.54608861],
#          [0.79811544, 0.55502661],
#          [0.45781744, 0.38455062],
#          [0.12390143, 0.33005062],
#          [0.71571144, 0.48919062],
#          [0.47264144, 0.75269263],
#          [0.56049544, 0.69906463],
#          [0.67734344, 0.66156863],
#          [0.50228944, 0.62952263],
#          [0.41334544, 0.17156462],
#          [0.91801543, 0.01089863],
#          [0.36887345, 0.03487863],
#          [0.99054945, 0.21974262],
#          [0.01555543, 0.01852863],
#          [0.81947943, 0.41071062],
#          [0.22477545, 0.15477862],
#          [0.98945945, 0.30389062],
#          [0.12035345, 0.42052062],
#          [0.38391545, 0.34138662],
#          [0.15981145, 0.61208263],
#          [0.23741945, 0.04032863],
#          [0.59995344, 0.99314662],
#          [0.63265344, 0.48657462],
#          [0.38587745, 0.85885863],
#          [0.78830544, 0.16655062],
#          [0.97223745, 0.57704461],
#          [0.44931544, 0.45910662],
#          [0.73838344, 0.35076062],
#          [0.07332543, 0.73808663],
#          [0.49269744, 0.81743863],
#          [0.50991944, 0.11880862],
#          [0.86024543, 0.24328662],
#          [0.32156745, 0.76206663],
#          [0.18444545, 0.35664662],
#          [0.66382744, 0.27271662],
#          [0.96264545, 0.26617662],
#          [0.48245144, 0.08828863],
#          [0.70023344, 0.93297862],
#          [0.62458744, 0.52363461],
#          [0.01947943, 0.85231863],
#          [0.00203944, 0.81525863],
#          [0.66012144, 0.75487263]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727,  1.1745195 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 1.5560293 ,  1.6097257 ,  0.43829894, ..., -0.53142697,
#                2.6505039 , -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 ,  1.1901603 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  2.569546  ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  0.9280585 ,
#                1.8772322 , -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.7110492 , 0.28998794],
#          [0.96386922, 0.73573795],
#          [0.0433752 , 0.55856394],
#          [0.93291322, 0.15177595],
#          [0.92135922, 0.29434794],
#          [0.6018312 , 0.68559795],
#          [0.8562372 , 0.89574995],
#          [0.15907322, 0.80898595],
#          [0.8577632 , 0.38743394],
#          [0.12811722, 0.39615394],
#          [0.19395321, 0.60973396],
#          [0.12702722, 0.79873995],
#          [0.90413722, 0.95722595],
#          [0.7095232 , 0.58254394],
#          [0.14512122, 0.47964794],
#          [0.57022121, 0.95940595],
#          [0.7481092 , 0.49861394],
#          [0.38056121, 0.06522995],
#          [0.98087321, 0.23832194],
#          [0.10086722, 0.45043594],
#          [0.47168521, 0.48248194],
#          [0.40410521, 0.34775794],
#          [0.7581372 , 0.74096995],
#          [0.47931521, 0.98076995],
#          [0.8390152 , 0.56139794],
#          [0.13465722, 0.95722595],
#          [0.95405922, 0.68668795],
#          [0.95798322, 0.18294995],
#          [0.36094121, 0.22807595],
#          [0.54842121, 0.26230194],
#          [0.0185232 , 0.43866394],
#          [0.92266722, 0.77715795],
#          [0.08299122, 0.70260195],
#          [0.36987921, 0.94588995],
#          [0.6665772 , 0.29347594],
#          [0.7681652 , 0.44629394],
#          [0.8316032 , 0.08354195],
#          [0.43135521, 0.56308196],
#          [0.13051522, 0.68559795],
#          [0.36987921, 0.66772195],
#          [0.21248321, 0.46700394],
#          [0.36115921, 0.30917194],
#          [0.28355121, 0.46656794],
#          [0.08735122, 0.48858594],
#          [0.48236721, 0.32682994],
#          [0.34437321, 0.99515795],
#          [0.24670921, 0.98273195],
#          [0.17847521, 0.55224194],
#          [0.52422321, 0.00418995],
#          [0.58046721, 0.61452996]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ...,  1.3460585 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  0.5677207 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  1.0160723 , ...,  1.536583  ,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 ,  1.0095302 , -0.43380988, ...,  0.86142814,
#               -0.32283673, -0.15858787],
#              [ 2.159917  , -0.43280727, -0.43380988, ..., -0.53142697,
#                2.1598265 , -0.15858787],
#              [-0.3077751 ,  1.0002092 , -0.43380988, ...,  0.85242695,
#                1.7632232 , -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.19660394, 0.78447203],
#          [0.88482992, 0.67503603],
#          [0.27530194, 0.83483003],
#          [0.84384592, 0.75286203],
#          [0.99464194, 0.96977202],
#          [0.95409394, 0.33043802],
#          [0.72721593, 0.94426602],
#          [0.73767993, 0.53420803],
#          [0.26788994, 0.78381803],
#          [0.68753993, 0.38646402],
#          [0.26745394, 0.71471203],
#          [0.20641394, 0.19745802],
#          [0.40435793, 0.23342802],
#          [0.22014794, 0.21751402],
#          [0.86346592, 0.61203403],
#          [0.32173594, 0.36248402],
#          [0.57199993, 0.08409802],
#          [0.51379393, 0.05881003],
#          [0.83621592, 0.99026402],
#          [0.94303592, 0.23081202],
#          [0.66486793, 0.30318802],
#          [0.49896993, 0.18263402],
#          [0.05801592, 0.33610602],
#          [0.03011192, 0.42962802],
#          [0.77234193, 0.78730603],
#          [0.68056393, 0.53072003],
#          [0.87676392, 0.36728002],
#          [0.73113993, 0.88867602],
#          [0.99333394, 0.42156202],
#          [0.58050193, 0.38842602],
#          [0.81267192, 0.85096203],
#          [0.08090592, 0.54990403],
#          [0.69865793, 0.90241002],
#          [0.32260794, 0.84355003],
#          [0.95888994, 0.73585803],
#          [0.84166592, 0.23996802],
#          [0.74770793, 0.66152003],
#          [0.09485792, 0.16236002],
#          [0.03359992, 0.57453803],
#          [0.82967592, 0.38559202],
#          [0.16368594, 0.08518802],
#          [0.65156993, 0.41894602],
#          [0.39040593, 0.54707003],
#          [0.31018194, 0.40804602],
#          [0.07044192, 0.88693202],
#          [0.25262994, 0.53399003],
#          [0.16128794, 0.54881403],
#          [0.23715194, 0.24105802],
#          [0.20510594, 0.31539602],
#          [0.79479592, 0.17086202]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  0.9341266 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  2.0020497 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.77207465, 0.98345003],
#          [0.75354465, 0.38335602],
#          [0.36294864, 0.41017002],
#          [0.49396664, 0.64424204],
#          [0.27160664, 0.76937403],
#          [0.49658264, 0.36853202],
#          [0.23236664, 0.52680002],
#          [0.79060465, 0.06093403],
#          [0.45886864, 0.85766403],
#          [0.02766465, 0.25669803],
#          [0.13470265, 0.76392403],
#          [0.33395464, 0.21462403],
#          [0.18571464, 0.47404402],
#          [0.80521065, 0.29615603],
#          [0.91769865, 0.23489803],
#          [0.53473264, 0.15358403],
#          [0.77142065, 0.64903804],
#          [0.36643664, 0.87270603],
#          [0.52797464, 0.40602802],
#          [0.19552464, 0.04066003],
#          [0.87170065, 0.78921203],
#          [0.77926865, 0.18977203],
#          [0.44622464, 0.41801802],
#          [0.77665265, 0.91194603],
#          [0.88281865, 0.99587603],
#          [0.69272265, 0.64358804],
#          [0.52056264, 0.57040002],
#          [0.36883464, 0.76501403],
#          [0.43597864, 0.47339002],
#          [0.38649264, 0.18890003],
#          [0.26027064, 0.42564802],
#          [0.30801264, 0.45595002],
#          [0.47347464, 0.68697004],
#          [0.63386265, 0.98279603],
#          [0.89895065, 0.93592603],
#          [0.26419464, 0.37681602],
#          [0.62383465, 0.43153402],
#          [0.34507264, 0.89843003],
#          [0.71931865, 0.35349002],
#          [0.30801264, 0.07772003],
#          [0.70972665, 0.03412003],
#          [0.45298264, 0.13919603],
#          [0.86843065, 0.38030402],
#          [0.87409865, 0.59983002],
#          [0.84881065, 0.01559003],
#          [0.94146064, 0.33626803],
#          [0.70798265, 0.05156003],
#          [0.35074064, 0.03455603],
#          [0.56628265, 0.91979403],
#          [0.35946064, 0.23184603]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  0.7882582 , ...,  2.0802855 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.9221368 ,  0.60006607, ...,  0.94322103,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727,  0.75353897, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  0.6968512 , -0.43380988, ...,  0.55947626,
#               -0.32283673, -0.15858787],
#              [ 2.3371868 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer V',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.6736355 , 0.80203466],
#          [0.38288349, 0.47901865],
#          [0.7747875 , 0.32859865],
#          [0.17905349, 0.98428266],
#          [0.7194155 , 0.52822667],
#          [0.6827915 , 0.52517467],
#          [0.46921149, 0.72311866],
#          [0.94809749, 0.78677466],
#          [0.34887549, 0.68954666],
#          [0.55357748, 0.08836266],
#          [0.46768549, 0.19561866],
#          [0.12673349, 0.32423865],
#          [0.14918749, 0.70546066],
#          [0.6675315 , 0.70066466],
#          [0.22853949, 0.74034066],
#          [0.11343549, 0.67101666],
#          [0.30135149, 0.85304666],
#          [0.88095349, 0.33840865],
#          [0.07484949, 0.95485266],
#          [0.0229655 , 0.87702666],
#          [0.44021749, 0.98842466],
#          [0.17425749, 0.22504866],
#          [0.8286335 , 0.72072066],
#          [0.8175155 , 0.01620466],
#          [0.7002315 , 0.15637866],
#          [0.07484949, 0.42757065],
#          [0.32860149, 0.94940266],
#          [0.13458149, 0.03974866],
#          [0.0362635 , 0.56942867],
#          [0.26930549, 0.31551865],
#          [0.94133949, 0.17120266],
#          [0.8382255 , 0.23137066],
#          [0.0133735 , 0.76497466],
#          [0.59979348, 0.96379066],
#          [0.8619875 , 0.28914065],
#          [0.0321215 , 0.30505465],
#          [0.8569735 , 0.82601466],
#          [0.41689149, 0.15376266],
#          [0.41819949, 0.07506466],
#          [0.46637749, 0.14242666],
#          [0.30680149, 0.39966665],
#          [0.27584549, 0.60648867],
#          [0.96422949, 0.06787066],
#          [0.7372915 , 0.81773066],
#          [0.92171949, 0.53722465],
#          [0.89991949, 0.63962466],
#          [0.51804348, 0.60518067],
#          [0.6799575 , 0.91888266],
#          [0.31857349, 0.11256066],
#          [0.52763548, 0.27148265]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  1.063163  , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 4.3521695 , -0.43280727, -0.43380988, ...,  2.5786493 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 ,  2.3997002 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.6553097 , -0.43380988, ...,  1.4850528 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  1.4294881 , ..., -0.53142697,
#                3.6834197 , -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_1',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer V',
#    'tissue_percentage': 0.94}},
#  {'normalized_positions': array([[0.54035314, 0.59834196],
#          [0.33565114, 0.69317196],
#          [0.72036115, 0.19438797],
#          [0.03415715, 0.46819596],
#          [0.50176714, 0.64368596],
#          [0.14991515, 0.09258197],
#          [0.82107715, 0.60291996],
#          [0.85486715, 0.37031396],
#          [0.79818715, 0.47233796],
#          [0.50547314, 0.14882597],
#          [0.70946115, 0.78255195],
#          [0.62989115, 0.09061997],
#          [0.29706514, 0.03917197],
#          [0.14054115, 0.60924196],
#          [0.84244115, 0.99874797],
#          [0.86336915, 0.60291996],
#          [0.46034714, 0.34676996],
#          [0.54645714, 0.52596596],
#          [0.02805315, 0.30818397],
#          [0.14991515, 0.43309796],
#          [0.43963714, 0.46383596],
#          [0.73518515, 0.96234197],
#          [0.10151915, 0.48476396],
#          [0.89890315, 0.37031396],
#          [0.28899914, 0.40911796],
#          [0.31690314, 0.69033796],
#          [0.64362515, 0.69644196],
#          [0.78750515, 0.60313796],
#          [0.68155715, 0.60989596],
#          [0.27744514, 0.18087197],
#          [0.38535514, 0.68663196],
#          [0.49958714, 0.58547996],
#          [0.78031115, 0.12767997],
#          [0.42394114, 0.62297596],
#          [0.93487315, 0.67311596],
#          [0.09628715, 0.04462197],
#          [0.68439115, 0.35025796],
#          [0.48585314, 0.71475396],
#          [0.31821114, 0.81067395],
#          [0.94969715, 0.74679996],
#          [0.81737115, 0.52116996],
#          [0.28180514, 0.68990196],
#          [0.94272115, 0.32344397],
#          [0.47277314, 0.64695596],
#          [0.18021715, 0.18239797],
#          [0.54798314, 0.39211396],
#          [0.25782514, 0.10435397],
#          [0.71600115, 0.87644997],
#          [0.63425115, 0.39102396],
#          [0.22512514, 0.18566797]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.4925537 , -0.43280727,  0.87651616, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [ 2.2715714 , -0.43280727, -0.43380988, ...,  1.190045  ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'corpus callosum',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.86508729, 0.82426657],
#          [0.6745553 , 0.70502057],
#          [0.90454529, 0.08639657],
#          [0.87184529, 0.12454657],
#          [0.5679533 , 0.57204058],
#          [0.79772529, 0.07113657],
#          [0.76698729, 0.11124857],
#          [0.83129729, 0.29736058],
#          [0.72665729, 0.19910257],
#          [0.71139729, 0.55285658],
#          [0.3822173 , 0.83189657],
#          [0.5208653 , 0.96378657],
#          [0.87598729, 0.88552457],
#          [0.3351293 , 0.78938657],
#          [0.85811129, 0.65052058],
#          [0.90389129, 0.24918259],
#          [0.3479913 , 0.54893258],
#          [0.92590929, 0.14830857],
#          [0.3015573 , 0.39458858],
#          [0.96841929, 0.80421057],
#          [0.5784173 , 0.50794858],
#          [0.82715529, 0.55830658],
#          [0.5873553 , 0.98558657],
#          [0.6326993 , 0.22062459],
#          [0.6381493 , 0.05631257],
#          [0.3678293 , 0.39546058],
#          [0.6333533 , 0.93457457],
#          [0.3902833 , 0.67668057],
#          [0.3135473 , 0.10688857],
#          [0.86748529, 0.70567457],
#          [0.3970413 , 0.62806658],
#          [0.3061353 , 0.85326057],
#          [0.3833073 , 0.45214058],
#          [0.5018993 , 0.75625057],
#          [0.83086129, 0.13392057],
#          [0.80143129, 0.90318257],
#          [0.89669729, 0.80268457],
#          [0.6111173 , 0.12171257],
#          [0.77069329, 0.73881057],
#          [0.4458733 , 0.14787257],
#          [0.4131733 , 0.93697257],
#          [0.6983173 , 0.84563057],
#          [0.5219553 , 0.89337257],
#          [0.6579873 , 0.68845257],
#          [0.4236373 , 0.81205857],
#          [0.70180529, 0.34793658],
#          [0.93942529, 0.56724458],
#          [0.72425929, 0.51775858],
#          [0.4127373 , 0.23850059],
#          [0.4059793 , 0.36232458]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  1.2880744 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  1.9689925 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                2.5600677 ,  6.122815  ]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.35408012, 0.92527852],
#          [0.53589211, 0.04876053],
#          [0.26382812, 0.63577453],
#          [0.03651411, 0.33297254],
#          [0.68020811, 0.30136254],
#          [0.48226411, 0.39837254],
#          [0.35560612, 0.10238852],
#          [0.0829481 , 0.78379653],
#          [0.00599411, 0.38834454],
#          [0.19973612, 0.64449453],
#          [0.52869811, 0.99367079],
#          [0.98709212, 0.29286054],
#          [0.46373411, 0.51107853],
#          [0.67672011, 0.91241652],
#          [0.50668011, 0.67893853],
#          [0.50995011, 0.53832853],
#          [0.61153811, 0.29395054],
#          [0.51104011, 0.18931054],
#          [0.67432211, 0.26059654],
#          [0.93346412, 0.36131254],
#          [0.57644011, 0.83720653],
#          [0.21434212, 0.08560253],
#          [0.62352811, 0.35586254],
#          [0.8574421 , 0.55467853],
#          [0.19079812, 0.23247454],
#          [0.68936411, 0.18931054],
#          [0.0670341 , 0.68220853],
#          [0.22088212, 0.71796053],
#          [0.32748412, 0.16168452],
#          [0.02430611, 0.76112453],
#          [0.20191612, 0.42714854],
#          [0.96594612, 0.74913453],
#          [0.45937411, 0.45897654],
#          [0.03062811, 0.47794253],
#          [0.31549412, 0.62727253],
#          [0.63181211, 0.84396453],
#          [0.27211212, 0.85464653],
#          [0.58516011, 0.63904453],
#          [0.71944811, 0.08298653],
#          [0.60238211, 0.74368453],
#          [0.71421611, 0.58563453],
#          [0.8713941 , 0.19258054],
#          [0.1125961 , 0.65168853],
#          [0.49054811, 0.73692653],
#          [0.24508012, 0.73387453],
#          [0.60630611, 0.18604054],
#          [0.00948211, 0.69463453],
#          [0.07787412, 0.42671254],
#          [0.99886412, 0.76548453],
#          [0.81362411, 0.87470253]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  2.7877572 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  2.749952  , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  1.2536983 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727,  2.2947915 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.426812  ,  0.82524073, ..., -0.53142697,
#                2.3842342 , -0.15858787],
#              [ 2.8067718 ,  1.7197075 ,  3.0817184 , ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.71534885, 0.7105177 ],
#          [0.19214886, 0.53132171],
#          [0.28305486, 0.8027317 ],
#          [0.87857087, 0.20846372],
#          [0.61201685, 0.29130371],
#          [0.84941885, 0.15963172],
#          [0.52808686, 0.0127597 ],
#          [0.74586885, 0.20410372],
#          [0.53375486, 0.66037771],
#          [0.60482285, 0.59279771],
#          [0.65278285, 0.52216571],
#          [0.90015287, 0.41229371],
#          [0.77115685, 0.7198917 ],
#          [0.65605285, 0.11995572],
#          [0.42279286, 0.7390757 ],
#          [0.33755486, 0.03362772],
#          [0.30638086, 0.05978772],
#          [0.18321086, 0.45393171],
#          [0.57888086, 0.26884972],
#          [0.75131885, 0.49229971],
#          [0.63752285, 0.7055037 ],
#          [0.54051286, 0.65383771],
#          [0.04042087, 0.25969372],
#          [0.06549087, 0.7911777 ],
#          [0.96075687, 0.65100371],
#          [0.47576686, 0.47529571],
#          [0.20086886, 0.58909171],
#          [0.98560886, 0.21936372],
#          [0.22048886, 0.40095771],
#          [0.79164885, 0.06000572],
#          [0.64144685, 0.65667171],
#          [0.17143887, 0.21042572],
#          [0.45483886, 0.50690571],
#          [0.01840287, 0.14807772],
#          [0.90996287, 0.61852171],
#          [0.34867286, 0.7532457 ],
#          [0.86919687, 0.89205172],
#          [0.95443487, 0.04648972],
#          [0.58171486, 0.55835371],
#          [0.79529487, 0.8029497 ],
#          [0.64733285, 0.01466172],
#          [0.82500285, 0.57513971],
#          [0.89339487, 0.32618371],
#          [0.10800087, 0.29413771],
#          [0.97972286, 0.83537172],
#          [0.73257085, 0.14437172],
#          [0.08053287, 0.51998571],
#          [0.98124886, 0.35495971],
#          [0.96707887, 0.59279771],
#          [0.96991287, 0.08180572]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  1.6347764 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.75969848, 0.87986072],
#          [0.9488625 , 0.36363673],
#          [0.21251849, 0.67188872],
#          [0.49439249, 0.99322071],
#          [0.1608525 , 0.27992473],
#          [0.26026049, 0.74186672],
#          [0.49744449, 0.85086672],
#          [0.9094045 , 0.64856272],
#          [0.22014849, 0.96662471],
#          [0.48414649, 0.93000072],
#          [0.9665205 , 0.95768672],
#          [0.73898848, 0.54326872],
#          [0.87850848, 0.16379071],
#          [0.79545048, 0.98014071],
#          [0.78694848, 0.34794073],
#          [0.26898049, 0.16967671],
#          [0.04515448, 0.65989872],
#          [0.23802449, 0.84716072],
#          [0.9181245 , 0.94896672],
#          [0.60840649, 0.61411872],
#          [0.0267825 , 0.56070872],
#          [0.86739048, 0.35491673],
#          [0.72045848, 0.28493873],
#          [0.68623248, 0.02688672],
#          [0.21535249, 0.60736072],
#          [0.32108249, 0.01576872],
#          [0.72852448, 0.96488071],
#          [0.1608525 , 0.46239073],
#          [0.84232048, 0.84280072],
#          [0.9939885 , 0.84280072],
#          [0.1601985 , 0.89359472],
#          [0.1839605 , 0.50424673],
#          [0.55630449, 0.13915672],
#          [0.26353049, 0.30499473],
#          [0.89464048, 0.89250472],
#          [0.22559849, 0.80290672],
#          [0.35291049, 0.12149872],
#          [0.54082649, 0.68889272],
#          [0.73353848, 0.82645072],
#          [0.1490805 , 0.23523473],
#          [0.39956249, 0.66992672],
#          [0.8461845 , 0.74644472],
#          [0.27922649, 0.69477872],
#          [0.9346925 , 0.88988872],
#          [0.1580185 , 0.02732272],
#          [0.1523505 , 0.98842471],
#          [0.59162049, 0.04062072],
#          [0.8736525 , 0.62000472],
#          [0.28642049, 0.60801472],
#          [0.68906648, 0.47372673]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  2.5314345 ,  2.7750883 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.5916018 , -0.43280727,  1.561432  , ...,  1.4036354 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  2.7690501 , ...,  0.96396273,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 0.98}},
#  {'normalized_positions': array([[0.45145774, 0.53365983],
#          [0.57506374, 0.77993984],
#          [0.33706772, 0.45823183],
#          [0.75513173, 0.88109184],
#          [0.45516374, 0.99445183],
#          [0.94261173, 0.64368984],
#          [0.31374172, 0.81220384],
#          [0.52753974, 0.72107984],
#          [0.74314173, 0.94474784],
#          [0.78652373, 0.79672584],
#          [0.51424174, 0.92730784],
#          [0.08375173, 0.54390583],
#          [0.36164174, 0.29778383],
#          [0.80766973, 0.98900183],
#          [0.41614174, 0.67093984],
#          [0.18119773, 0.31783983],
#          [0.46148574, 0.69404784],
#          [0.67643373, 0.42858383],
#          [0.62062574, 0.63213584],
#          [0.68515373, 0.34792383],
#          [0.05126973, 0.14169584],
#          [0.12582573, 0.16327784],
#          [0.81551773, 0.35032183],
#          [0.42093774, 0.82114184],
#          [0.45647174, 0.57246383],
#          [0.25749773, 0.57878583],
#          [0.04778173, 0.53082583],
#          [0.23504373, 0.84294184],
#          [0.69757973, 0.49812583],
#          [0.18795573, 0.67704384],
#          [0.84363973, 0.89329984],
#          [0.01137573, 0.65219184],
#          [0.05977173, 0.70581984],
#          [0.67250974, 0.50161383],
#          [0.88222573, 0.30737583],
#          [0.34550974, 0.77514384],
#          [0.37711974, 0.41768383],
#          [0.43140174, 0.39915383],
#          [0.49614774, 0.55022783],
#          [0.29433972, 0.31347983],
#          [0.83426573, 0.83422184],
#          [0.68406373, 0.98071783],
#          [0.74117973, 0.81743584],
#          [0.17465773, 0.60320182],
#          [0.13127573, 0.10463584],
#          [0.62542174, 0.73699384],
#          [0.64373374, 0.82920784],
#          [0.56045774, 0.85122584],
#          [0.95154973, 0.88872184],
#          [0.17073373, 0.39806383]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  1.9019738 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.3713655 ,  2.3290431 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.0232677 , -0.43280727, -0.43380988, ...,  1.0243256 ,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 2.2093592 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'cortical layer II/III',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.73494144, 0.5070282 ],
#          [0.38505145, 0.77096622],
#          [0.79816144, 0.30319821],
#          [0.54244745, 0.41219821],
#          [0.32357545, 0.04922822],
#          [0.83522144, 0.35791621],
#          [0.58648345, 0.11244821],
#          [0.34668345, 0.59918222],
#          [0.68414744, 0.93228621],
#          [0.21566545, 0.13599221],
#          [0.16290946, 0.26810021],
#          [0.96253344, 0.23213021],
#          [0.20803545, 0.37601021],
#          [0.63073744, 0.19485221],
#          [0.45808145, 0.22341021],
#          [0.08863144, 0.95539421],
#          [0.41186545, 0.12378421],
#          [0.90906346, 0.09980421],
#          [0.54288345, 0.69183222],
#          [0.02650144, 0.88062021],
#          [0.26144545, 0.17109021],
#          [0.88100144, 0.40544021],
#          [0.42254745, 0.95277821],
#          [0.81211344, 0.90983221],
#          [0.48598545, 0.61989222],
#          [0.64468944, 0.95059821],
#          [0.72164344, 0.5501922 ],
#          [0.12176744, 0.66044022],
#          [0.19975145, 0.32543421],
#          [0.94263546, 0.64300022],
#          [0.94154546, 0.79015022],
#          [0.62441544, 0.39497621],
#          [0.25054545, 0.4795602 ],
#          [0.65275544, 0.37470221],
#          [0.62768544, 0.29535021],
#          [0.54833345, 0.63864022],
#          [0.90062144, 0.68289422],
#          [0.14001946, 0.39846421],
#          [0.06617744, 0.64256422],
#          [0.56010545, 0.35987821],
#          [0.87206344, 0.66371022],
#          [0.41818745, 0.01543822],
#          [0.95446744, 0.40696621],
#          [0.35758345, 0.68485622],
#          [0.59672945, 0.91353821],
#          [0.65776944, 0.08454421],
#          [0.59694745, 0.33873221],
#          [0.72534944, 0.71341422],
#          [0.55792545, 0.4893702 ],
#          [0.76764144, 0.4760722 ]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727,  2.8310082 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.485142  , -0.43380988, ..., -0.53142697,
#               -0.32283673,  5.9247103 ],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [ 2.1125054 , -0.43280727,  1.9875822 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  3.7036042 , ...,  1.33753   ,
#               -0.32283673, -0.15858787],
#              [ 1.956746  , -0.43280727,  3.0224845 , ..., -0.53142697,
#                1.9554226 , -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_2',
#    'slice_id': '1',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.20633394, 0.31250185],
#          [0.53501796, 0.34258585],
#          [0.24426594, 0.45087186],
#          [0.69960795, 0.01514986],
#          [0.73448795, 0.13395985],
#          [0.12349395, 0.63377386],
#          [0.14311395, 0.44193386],
#          [0.38029794, 0.98824185],
#          [0.08795995, 0.97537985],
#          [0.27325994, 0.53000586],
#          [0.41038194, 0.96208185],
#          [0.37026994, 0.51234786],
#          [0.22333794, 0.69503186],
#          [0.42187596, 0.37724785],
#          [0.39555794, 0.06572585],
#          [0.42193594, 0.63856986],
#          [0.78528195, 0.05765985],
#          [0.18344394, 0.40639987],
#          [0.81819995, 0.20960585],
#          [0.23663594, 0.18976785],
#          [0.67780795, 0.26170785],
#          [0.15771995, 0.27086385],
#          [0.19979394, 0.13657585],
#          [0.41773396, 0.13352385],
#          [0.10321995, 0.67192386],
#          [0.18409794, 0.95881185],
#          [0.38204194, 0.15510585],
#          [0.41038194, 0.87836985],
#          [0.12937995, 0.34906587],
#          [0.25538394, 0.17973985],
#          [0.55572795, 0.29658785],
#          [0.17842994, 0.84392585],
#          [0.97123594, 0.27805785],
#          [0.09144795, 0.87662585],
#          [0.31446194, 0.02277986],
#          [0.10648995, 0.14311585],
#          [0.36896194, 0.43103386],
#          [0.39185194, 0.19325585],
#          [0.80708195, 0.06572585],
#          [0.34498194, 0.13919185],
#          [0.25429394, 0.77133186],
#          [0.17777594, 0.59453386],
#          [0.42476994, 0.71443386],
#          [0.09144795, 0.02321586],
#          [0.04610395, 0.69786586],
#          [0.29048194, 0.48160986],
#          [0.02103395, 0.45937386],
#          [0.29222594, 0.13940985],
#          [0.35871594, 0.34127785],
#          [0.40972794, 0.79705586]]),
#   'gene_expressions': ArrayView([[ 5.662605  , -0.43280727, -0.43380988, ...,  1.8317069 ,
#               -0.32283673, -0.15858787],
# ...
#          [0.17480421, 0.24717068],
#          [0.99420621, 0.26090467],
#          [0.99595021, 0.42614867],
#          [0.69968822, 0.77015266],
#          [0.4425082 , 0.53296867],
#          [0.25764421, 0.55738467],
#          [0.91529021, 0.43203467],
#          [0.66132022, 0.28183267],
#          [0.75353422, 0.40805467],
#          [0.26135021, 0.21817668],
#          [0.6424142 , 0.45100067],
#          [0.64279022, 0.05751068],
#          [0.07343421, 0.19441468],
#          [0.4368402 , 0.51160467],
#          [0.35094821, 0.79647068],
#          [0.11681621, 0.29273267],
#          [0.17545821, 0.71870466],
#          [0.07343421, 0.51814467],
#          [0.19246221, 0.02072866],
#          [0.61248822, 0.25065868],
#          [0.82547421, 0.30624867],
#          [0.3962922 , 0.09173668],
#          [0.25415621, 0.76819066],
#          [0.65390822, 0.97457668],
#          [0.70884422, 0.36358267],
#          [0.31236221, 0.67750266],
#          [0.22690621, 0.72982266],
#          [0.4305182 , 0.99419668],
#          [0.77533421, 0.83091468],
#          [0.6114582 , 0.42593067],
#          [0.06297021, 0.12509068],
#          [0.08215421, 0.42898267],
#          [0.30298821, 0.84246868],
#          [0.67178422, 0.91571668],
#          [0.82918021, 0.60229267],
#          [0.63450622, 0.87211668],
#          [0.77315421, 0.93599068],
#          [0.3999982 , 0.36510867],
#          [0.3836482 , 0.26918867],
#          [0.85163421, 0.43857467],
#          [0.4154762 , 0.85772868],
#          [0.93992421, 0.49242067]]),
#   'gene_expressions': ArrayView([[-0.3077751 ,  2.9379334 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  1.0702438 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727,  1.6908331 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  3.238374  , ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.3635725 , 0.26190969],
#          [0.1475345 , 0.04260169],
#          [0.0640405 , 0.99781769],
#          [0.9883005 , 0.58869168],
#          [0.44837449, 0.47598568],
#          [0.3478765 , 0.54879768],
#          [0.3177925 , 0.68853568],
#          [0.45818449, 0.41930569],
#          [0.1061145 , 0.54770768],
#          [0.3005705 , 0.54574568],
#          [0.9381605 , 0.40469969],
#          [0.57786649, 0.85459169],
#          [0.44074449, 0.31074169],
#          [0.47235449, 0.27237369],
#          [0.73345851, 0.93307169],
#          [0.1344545 , 0.96075769],
#          [0.0271985 , 0.67000568],
#          [0.2484685 , 0.90734769],
#          [0.0014745 , 0.36654969],
#          [0.50941449, 0.63643368],
#          [0.9752205 , 0.92042769],
#          [0.2066125 , 0.97972369],
#          [0.73912651, 0.03606169],
#          [0.7689925 , 0.82516169],
#          [0.3690225 , 0.83017569],
#          [0.8200045 , 0.85546369],
#          [0.39801649, 0.39794169],
#          [0.45491449, 0.49407968],
#          [0.54102449, 0.41232969],
#          [0.9741305 , 0.02407169],
#          [0.73563851, 0.59217968],
#          [0.3788325 , 0.14942169],
#          [0.61835451, 0.7686997 ],
#          [0.8455105 , 0.34365969],
#          [0.9475345 , 0.7885377 ],
#          [0.72103251, 0.14767769],
#          [0.1460085 , 0.49538768],
#          [0.58571449, 0.09884569],
#          [0.1643205 , 0.33864569],
#          [0.66064651, 0.54705368],
#          [0.51660849, 0.32687369],
#          [0.3214985 , 0.19171369],
#          [0.0500885 , 0.39096569],
#          [0.9198485 , 0.35019969],
#          [0.0823525 , 0.08140569],
#          [0.51486449, 0.44677368],
#          [0.66609651, 0.15356369],
#          [0.52750849, 0.05611769],
#          [0.3541985 , 0.59479568],
#          [0.46864849, 0.06701769]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.4349086 , -0.43380988, ..., -0.53142697,
#                2.3960204 , -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                4.3245063 , -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer II/III',
#    'tissue_percentage': 0.9}},
#  {'normalized_positions': array([[0.76022486, 0.75245668],
#          [0.08644685, 0.75027668],
#          [0.23425085, 0.39450069],
#          [0.91783885, 0.76052268],
#          [0.42036286, 0.27983269],
#          [0.02649685, 0.03153069],
#          [0.53786486, 0.17650069],
#          [0.94617885, 0.60334468],
#          [0.14290885, 0.57304268],
#          [0.59236486, 0.0191047 ],
#          [0.31506887, 0.81524068],
#          [0.83281885, 0.31907269],
#          [0.99719085, 0.29683669],
#          [0.09647485, 0.92854069],
#          [0.97735285, 0.05376669],
#          [0.29675687, 0.19873669],
#          [0.33163687, 0.72586068],
#          [0.64294086, 0.96342069],
#          [0.82322685, 0.42741869],
#          [0.03129285, 0.70842068],
#          [0.34842287, 0.56257868],
#          [0.54004486, 0.60770468],
#          [0.08535685, 0.04134069],
#          [0.61787086, 0.61904068],
#          [0.06203085, 0.97475669],
#          [0.68763086, 0.46164468],
#          [0.14116485, 0.19503069],
#          [0.43714886, 0.15949669],
#          [0.88535685, 0.72084668],
#          [0.51105086, 0.23296269],
#          [0.61917886, 0.40779869],
#          [0.70877686, 0.40823469],
#          [0.29223885, 0.42458469],
#          [0.34428087, 0.62819668],
#          [0.24160287, 0.61773268],
#          [0.48728886, 0.05862267],
#          [0.63443886, 0.23296269],
#          [0.96776085, 0.42349469],
#          [0.35169287, 0.05703669],
#          [0.38330287, 0.43286869],
#          [0.52260486, 0.07207869],
#          [0.68937486, 0.86880869],
#          [0.07881685, 0.86096069],
#          [0.55356086, 0.34414269],
#          [0.21092485, 0.98870869],
#          [0.76218686, 0.66220468],
#          [0.64141486, 0.91764069],
#          [0.28629287, 0.55342268],
#          [0.10388685, 0.40779869],
#          [0.52958086, 0.70231668]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.8374794 , -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#                4.654697  , -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer V',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.85264069, 0.19802674],
#          [0.4342987 , 0.83343675],
#          [0.34230271, 0.92499674],
#          [0.6830367 , 0.34822874],
#          [0.82212069, 0.38071074],
#          [0.26519069, 0.25318074],
#          [0.06702869, 0.07354875],
#          [0.7453847 , 0.95900474],
#          [0.6433607 , 0.00820873],
#          [0.05264069, 0.38899474],
#          [0.79399869, 0.21415874],
#          [0.29761271, 0.65386473],
#          [0.6437967 , 0.27192874],
#          [0.7299067 , 0.25470674],
#          [0.95204869, 0.99301274],
#          [0.01514469, 0.87180475],
#          [0.28699069, 0.14810474],
#          [0.17537469, 0.36043674],
#          [0.4652547 , 0.87638275],
#          [0.5162667 , 0.12848474],
#          [0.09100869, 0.75915873],
#          [0.14202069, 0.49886674],
#          [0.33532671, 0.69245073],
#          [0.79356269, 0.07856275],
#          [0.4489047 , 0.29416474],
#          [0.5295647 , 0.47597674],
#          [0.5441707 , 0.82340875],
#          [0.6627627 , 0.31749074],
#          [0.96403869, 0.27389074],
#          [0.04108669, 0.59347873],
#          [0.01056669, 0.74433473],
#          [0.7275087 , 0.77768873],
#          [0.26083069, 0.95028474],
#          [0.19848269, 0.66803473],
#          [0.82735269, 0.69964473],
#          [0.5463507 , 0.69005273],
#          [0.03214869, 0.79877475],
#          [0.4053047 , 0.71446873],
#          [0.09863869, 0.85305675],
#          [0.7081067 , 0.50933074],
#          [0.08403269, 0.09818275],
#          [0.19325069, 0.72929273],
#          [0.15466469, 0.63293673],
#          [0.88337869, 0.11998274],
#          [0.85503869, 0.65233873],
#          [0.21134469, 0.99693674],
#          [0.6573127 , 0.20892674],
#          [0.7222767 , 0.09600275],
#          [0.06528469, 0.71425073],
#          [0.5925667 , 0.89077075]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  3.5618913 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.3209083 ,  0.75353885, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 ,  1.4938011 ,  3.4034586 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727,  1.2967459 , ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'striatum',
#    'tissue_percentage': 1.0}},
#  {'normalized_positions': array([[0.81428105, 0.44074485],
#          [0.47731304, 0.77014284],
#          [0.94944105, 0.11511284],
#          [0.04589105, 0.22389484],
#          [0.07096105, 0.08873484],
#          [0.23271705, 0.75706285],
#          [0.02736105, 0.11184284],
#          [0.42521104, 0.14388884],
#          [0.65034506, 0.78889084],
#          [0.19979905, 0.03881284],
#          [0.62985306, 0.90246884],
#          [0.52303306, 0.48347285],
#          [0.74452106, 0.21670084],
#          [0.35675905, 0.22236884],
#          [0.39076704, 0.69318885],
#          [0.43741904, 0.01265284],
#          [0.90802105, 0.92753884],
#          [0.91892105, 0.69820285],
#          [0.31424905, 0.15544284],
#          [0.17451105, 0.72785085],
#          [0.06681905, 0.47279085],
#          [0.05003305, 0.51900685],
#          [0.70070306, 0.36270085],
#          [0.68369906, 0.04731484],
#          [0.76980905, 0.98400084],
#          [0.04828905, 0.34902684],
#          [0.23533305, 0.64719085],
#          [0.14181105, 0.95326284],
#          [0.24579705, 0.98901484],
#          [0.28547305, 0.84469884],
#          [0.21876505, 0.12688484],
#          [0.86616505, 0.26248084],
#          [0.37812304, 0.93952884],
#          [0.11717705, 0.41284085],
#          [0.23511505, 0.55955485],
#          [0.24710505, 0.30477284],
#          [0.25473505, 0.23043484],
#          [0.72773506, 0.72370885],
#          [0.73296706, 0.58091885],
#          [0.16818905, 0.42701085],
#          [0.75149706, 0.17964084],
#          [0.45158904, 0.29866884],
#          [0.39490904, 0.86758884],
#          [0.86507505, 0.95522484],
#          [0.62571106, 0.40717285],
#          [0.30400305, 0.54233285],
#          [0.54526906, 0.17985884],
#          [0.33517705, 0.25746684],
#          [0.13200105, 0.08982484],
#          [0.07706505, 0.69406085]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 1.355893  , -0.43280727,  0.8225191 , ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [ 4.271781  , -0.43280727, -0.43380988, ..., -0.53142697,
#                4.2845025 , -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer VI',
#    'tissue_percentage': 0.94}},
#  {'normalized_positions': array([[0.70451019, 0.4343475 ],
#          [0.13210219, 0.49277149],
#          [0.88566819, 0.48688549],
#          [0.74920019, 0.3940175 ],
#          [0.86670219, 0.65315951],
#          [0.5828662 , 0.59806549],
#          [0.27205819, 0.00292551],
#          [0.6591662 , 0.50061949],
#          [0.6657062 , 0.2383655 ],
#          [0.94082219, 0.78286951],
#          [0.83727219, 0.3373375 ],
#          [0.36470818, 0.8896895 ],
#          [0.79083819, 0.1810315 ],
#          [0.79280019, 0.3194615 ],
#          [0.17766419, 0.46421349],
#          [0.24720619, 0.9790695 ],
#          [0.97330419, 0.2845815 ],
#          [0.84424819, 0.2810935 ],
#          [0.4287402 , 0.1559615 ],
#          [0.5157222 , 0.60089949],
#          [0.22998419, 0.58302349],
#          [0.6508822 , 0.3794115 ],
#          [0.16087819, 0.1529095 ],
#          [0.10986619, 0.2534075 ],
#          [0.82920619, 0.4223575 ],
#          [0.83443819, 0.57757349],
#          [0.12839619, 0.44502949],
#          [0.17635619, 0.63076549],
#          [0.4590422 , 0.70068351],
#          [0.05144219, 0.52547149],
#          [0.5902782 , 0.2887235 ],
#          [0.3881922 , 0.55119549],
#          [0.4784442 , 0.51871349],
#          [0.5264042 , 0.1250055 ],
#          [0.05296819, 0.0964475 ],
#          [0.10005619, 0.1315455 ],
#          [0.4681982 , 0.2078455 ],
#          [0.77732219, 0.53811549],
#          [0.02310219, 0.81033751],
#          [0.01024019, 0.2551515 ],
#          [0.22518819, 0.3318875 ],
#          [0.31609418, 0.2915575 ],
#          [0.06626619, 0.9707855 ],
#          [0.87760219, 0.01665951],
#          [0.3450282 , 0.52743349],
#          [0.27598219, 0.2161295 ],
#          [0.91139219, 0.53549949],
#          [0.04730019, 0.57931749],
#          [0.96240419, 0.9751455 ],
#          [0.5809042 , 0.1411375 ]]),
#   'gene_expressions': ArrayView([[-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              ...,
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ...,  2.9956686 ,
#               -0.32283673, -0.15858787],
#              [-0.3077751 , -0.43280727, -0.43380988, ..., -0.53142697,
#               -0.32283673, -0.15858787]], dtype=float32),
#   'metadata': {'platform': 'MERFISH',
#    'dataset': 'MouseBrainAging',
#    'donor_id': 'MsBrainAgingSpatialDonor_12',
#    'slice_id': '0',
#    'dominant_tissue': 'cortical layer II/III',
#    'tissue_percentage': 0.94}}]

# %%
# Initialize dictionaries to store metrics
metrics = {
    'GANBaseline': {
        'mse': [],
        'f1': [],
        'cosine_sim': [],
        'chamfer_dist': [],
        'emd': []
    }
}

# %%
test_item.test_area.hole_max_x
# Out:
# -4165.913093647361

# %%
for i, test_item in enumerate(all_test_items):
    print(f"Test Area {i+1}:")
    print(f"  Dominant Tissue: {test_item.test_area.dominant_tissue}")
    print(f"  Number of cells in ground truth: {len(test_item.ground_truth.hole_cells)}")
    
    # filter out  current slice from the training samples
    current_donor = test_item.meta_data['donor_id']
    current_slice = test_item.meta_data['slice_id']
    print(f'current_donor: {current_donor}')
    print(f'current_slice: {current_slice}')

    filtered_samples = [sample for sample in training_samples if not (sample['metadata']['donor_id'] == current_donor and sample['metadata']['slice_id'] == current_slice)]

    dataset = STDataset(filtered_samples)
    dataloader = DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)

    # Apply GANBaseline
    gan_baseline = GANBaseline(test_item.adata, test_item.test_area, dataloader, num_epochs=10)

    gan_coords, gan_gene_expressions = gan_baseline.fill_region()

    # Evaluate predictions for GANBaseline
    true_coords = test_item.ground_truth.hole_cells[['center_x', 'center_y']].values
    true_gene_expressions = test_item.ground_truth.gene_expression

    mse_gan, f1_gan, cosine_sim_gan = Evaluator.evaluate_expression(true_coords, true_gene_expressions, gan_coords, gan_gene_expressions)
    chamfer_dist_gan = Evaluator.chamfer_distance(true_coords, gan_coords)
    emd_gan = Evaluator.calculate_emd(true_coords, gan_coords)

    # Collect results for KNNBaseline
    metrics['GANBaseline']['mse'].append(mse_gan)
    metrics['GANBaseline']['f1'].append(f1_gan)
    metrics['GANBaseline']['cosine_sim'].append(cosine_sim_gan)
    metrics['GANBaseline']['chamfer_dist'].append(chamfer_dist_gan)
    metrics['GANBaseline']['emd'].append(emd_gan)
# Out:
# Test Area 1:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.20117241144180298, g_loss: 3.5646862983703613
# Test Area 2:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.4711822271347046, g_loss: 2.8742623329162598
# Test Area 3:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.3205311894416809, g_loss: 3.433074951171875
# Test Area 4:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.2198580801486969, g_loss: 3.601646900177002
# Test Area 5:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.2960074841976166, g_loss: 2.7018070220947266
# Test Area 6:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.20401284098625183, g_loss: 3.111170768737793
# Test Area 7:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.25318968296051025, g_loss: 3.2046308517456055
# Test Area 8:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.17589183151721954, g_loss: 3.640814781188965
# Test Area 9:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.21217022836208344, g_loss: 3.2575697898864746
# Test Area 10:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# Epoch [10/10], d_loss: 0.2961055636405945, g_loss: 2.937405586242676
# Test Area 11:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_2
# current_slice: 0
# Epoch [10/10], d_loss: 0.6025002598762512, g_loss: 3.4868884086608887
# Test Area 12:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_2
# current_slice: 0
# Epoch [10/10], d_loss: 0.23551499843597412, g_loss: 3.472024440765381
# Test Area 13:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_2
# current_slice: 0
# Epoch [10/10], d_loss: 0.24925285577774048, g_loss: 3.278205394744873
# Test Area 14:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_2
# current_slice: 0
# Epoch [10/10], d_loss: 0.2493257224559784, g_loss: 3.298708200454712
# Test Area 15:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_2
# current_slice: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 20
#      17 # Apply GANBaseline
#      18 gan_baseline = GANBaseline(test_item.adata, test_item.test_area, dataloader, num_epochs=10)
# ---> 20 gan_coords, gan_gene_expressions = gan_baseline.fill_region()
#      22 # Evaluate predictions for GANBaseline
#      23 true_coords = test_item.ground_truth.hole_cells[['center_x', 'center_y']].values
#
# File e:\Emory\Work\UCI_Completion\DISCO\baseline.py:384, in GANBaseline.fill_region(self)
#     381 self.generator.to(device)
#     382 self.discriminator.to(device)
# --> 384 self.generator, self.discriminator, slice_shape = self.train_gan(num_epochs=self.num_epochs)
#     386 # Generate the missing slice
#     387 noise = torch.randn(1, slice_shape[0], slice_shape[1]).to(device)
#
# File e:\Emory\Work\UCI_Completion\DISCO\baseline.py:416, in GANBaseline.train_gan(self, num_epochs)
#     413 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     415 for epoch in range(num_epochs):
# --> 416     for batch in self.training_dataloader:
#     417         positions = batch['positions'].to(device)
#     418         expressions = batch['expressions'].to(device)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\site-packages\torch\utils\data\dataloader.py:440, in DataLoader.__iter__(self)
#     438     return self._iterator
#     439 else:
# --> 440     return self._get_iterator()
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\site-packages\torch\utils\data\dataloader.py:388, in DataLoader._get_iterator(self)
#     386 else:
#     387     self.check_worker_number_rationality()
# --> 388     return _MultiProcessingDataLoaderIter(self)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\site-packages\torch\utils\data\dataloader.py:1038, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1031 w.daemon = True
#    1032 # NB: Process.start() actually take some time as it needs to
#    1033 #     start a process and pass the arguments over via a pipe.
#    1034 #     Therefore, we only add a worker to self._workers list after
#    1035 #     it started, so that we do not call .join() if program dies
#    1036 #     before it starts, and __del__ tries to join but will get:
#    1037 #     AssertionError: can only join a started process.
# -> 1038 w.start()
#    1039 self._index_queues.append(index_queue)
#    1040 self._workers.append(w)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\multiprocessing\popen_spawn_win32.py:95, in Popen.__init__(self, process_obj)
#      93 try:
#      94     reduction.dump(prep_data, to_child)
# ---> 95     reduction.dump(process_obj, to_child)
#      96 finally:
#      97     set_spawning_popen(None)
#
# File e:\Emory\Work\UCI_Completion\DISCO\.conda\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
for method in metrics:
    print(f"Results for {method}:")
    for metric in metrics[method]:
        mean_value = np.mean(metrics[method][metric])
        std_value = np.std(metrics[method][metric])
        print(f"  {metric.capitalize()}: Mean = {mean_value:.4f}, Std = {std_value:.4f}")
# Out:
# Results for GANBaseline:
#   Mse: Mean = 0.9371, Std = 0.3065
#   F1: Mean = 0.6545, Std = 0.0455
#   Cosine_sim: Mean = -0.0342, Std = 0.1118
#   Chamfer_dist: Mean = 173.0040, Std = 20.2853
#   Emd: Mean = 145.8393, Std = 12.3561

# %%
# Initialize dictionaries to store metrics
metrics = {
    'TissueGANBaseline': {
        'mse': [],
        'f1': [],
        'cosine_sim': [],
        'chamfer_dist': [],
        'emd': []
    }
}

# %%
for i, test_item in enumerate(all_test_items):
    print(f"Test Area {i+1}:")
    print(f"  Dominant Tissue: {test_item.test_area.dominant_tissue}")
    print(f"  Number of cells in ground truth: {len(test_item.ground_truth.hole_cells)}")
    
    # filter out  current slice from the training samples
    current_donor = test_item.meta_data['donor_id']
    current_slice = test_item.meta_data['slice_id']
    current_tissue = test_item.test_area.dominant_tissue
    print(f'current_donor: {current_donor}')
    print(f'current_slice: {current_slice}')

    # filtered_samples = [sample for sample in training_samples if not (sample['metadata']['donor_id'] == current_donor and sample['metadata']['slice_id'] == current_slice)]
    # filtered_samples = [sample for sample in filtered_samples if sample['metadata']['dominant_tissue'] == current_tissue]
    filtered_samples = [sample for sample in training_samples if  (sample['metadata']['donor_id'] == current_donor and sample['metadata']['slice_id'] == current_slice)]
    filtered_samples = [sample for sample in filtered_samples if sample['metadata']['dominant_tissue'] == current_tissue]
    print(len(filtered_samples))
    
    dataset = STDataset(filtered_samples)
    dataloader = DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)

    # Apply GANBaseline
    gan_baseline = GANBaseline(test_item.adata, test_item.test_area, dataloader, num_epochs=50)

    gan_coords, gan_gene_expressions = gan_baseline.fill_region()

    # Evaluate predictions for GANBaseline
    true_coords = test_item.ground_truth.hole_cells[['center_x', 'center_y']].values
    true_gene_expressions = test_item.ground_truth.gene_expression

    print(true_coords)
    print(gan_coords)
    print(max(true_coords[0]), max(true_coords[1]))
    print(max(gan_coords[0]), max(gan_coords[1]))

    mse_gan, f1_gan, cosine_sim_gan = Evaluator.evaluate_expression(true_coords, true_gene_expressions, gan_coords, gan_gene_expressions)
    chamfer_dist_gan = Evaluator.chamfer_distance(true_coords, gan_coords)
    emd_gan = Evaluator.calculate_emd(true_coords, gan_coords)

    # Collect results for KNNBaseline
    metrics['TissueGANBaseline']['mse'].append(mse_gan)
    metrics['TissueGANBaseline']['f1'].append(f1_gan)
    metrics['TissueGANBaseline']['cosine_sim'].append(cosine_sim_gan)
    metrics['TissueGANBaseline']['chamfer_dist'].append(chamfer_dist_gan)
    metrics['TissueGANBaseline']['emd'].append(emd_gan)

    break
# Out:
# Test Area 1:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# current_donor: MsBrainAgingSpatialDonor_1
# current_slice: 0
# 1
# Epoch [10/50], d_loss: 1.2368333339691162, g_loss: 2.06490159034729
# Epoch [20/50], d_loss: 1.113448977470398, g_loss: 1.9872255325317383
# Epoch [30/50], d_loss: 1.0303536653518677, g_loss: 1.9377881288528442
# Epoch [40/50], d_loss: 0.980897068977356, g_loss: 1.912305235862732
# Epoch [50/50], d_loss: 0.9483224153518677, g_loss: 1.9025253057479858
# [[-4282.49949084  1784.46449143]
#  [-4314.49099007  1825.88449043]
#  [-4219.82449235  1839.29149011]
#  [-4250.07199162  1800.37849104]
#  [-4189.14099309  1834.65899022]
#  [-4283.42599082  1880.22098912]
#  [-4208.27049263  1807.29999088]
#  [-4297.86849047  1811.38749078]
#  [-4245.87549172  1874.98898925]
#  [-4210.66849257  1858.80248964]
#  [-4292.6364906   1884.19948903]
#  [-4241.13399184  1815.58399068]
#  [-4177.36899337  1768.72898699]
#  [-4340.86898944  1822.77799051]
#  [-4338.79798949  1887.08798896]
#  [-4330.18698969  1887.46948895]
#  [-4194.42749296  1789.96899129]
#  [-4203.85599273  1852.69848979]
#  [-4346.5914893   1799.83349106]
#  [-4247.12899169  1833.24199025]
#  [-4251.37999159  1852.0989898 ]
#  [-4348.98948924  1853.07998978]
#  [-4339.61548947  1848.28398989]
#  [-4304.9534903   1857.49448967]
#  [-4256.77549146  1777.3249916 ]
#  [-4209.3059926   1830.13549033]
#  [-4296.50599051  1835.5309902 ]
#  [-4283.53499082  1760.811492  ]
#  [-4231.05149208  1825.01249045]
#  [-4209.3059926   1777.97899158]
#  [-4322.50248988  1839.94549009]
#  [-4287.62249072  1812.47749075]
#  [-4239.17199188  1765.07748708]
#  [-4166.91998881  1859.34748963]
#  [-4224.51149224  1769.25899179]
#  [-4309.58599019  1768.22349182]
#  [-4247.18349169  1775.63549164]
#  [-4182.11049326  1775.90799163]
#  [-4286.04199076  1822.45099051]
#  [-4310.18549018  1800.21499105]
#  [-4193.010493    1822.01499052]
#  [-4263.86049129  1765.62248707]
#  [-4260.42699137  1883.81798904]
#  [-4336.18198955  1777.92449158]
#  [-4229.68899211  1799.94249105]
#  [-4264.95049126  1850.19148985]
#  [-4167.5194888   1838.63749012]
#  [-4189.41349308  1774.76349166]
#  [-4179.56398851  1901.58498861]
#  [-4235.41149198  1873.62648928]]
# [[-4278.9375  1802.7699]
#  [-4276.448   1794.3202]
#  [-4243.775   1821.584 ]
#  [-4252.6924  1826.6422]
#  [-4269.207   1797.8602]
#  [-4240.992   1802.9849]
#  [-4236.832   1821.5973]
#  [-4241.485   1828.1805]
#  [-4240.0737  1801.8776]
#  [-4260.845   1816.0479]
#  [-4261.61    1806.4646]
#  [-4249.08    1819.5388]
#  [-4256.2397  1814.6854]
#  [-4242.6567  1816.5813]
#  [-4228.8857  1822.1406]
#  [-4239.9297  1812.9187]
#  [-4248.76    1804.4489]
#  [-4238.5747  1810.077 ]
#  [-4268.506   1822.1394]
#  [-4197.489   1832.9539]
#  [-4239.9243  1807.0663]
#  [-4233.0117  1826.98  ]
#  [-4223.914   1812.4716]
#  [-4256.7583  1804.5593]
#  [-4243.2393  1823.1694]
#  [-4222.3027  1810.5347]
#  [-4240.3877  1804.8363]
#  [-4268.5767  1806.4817]
#  [-4210.7666  1822.11  ]
#  [-4247.7603  1797.1613]
#  [-4262.0557  1805.6112]
#  [-4245.063   1813.668 ]
#  [-4243.9526  1823.279 ]
#  [-4237.2744  1821.217 ]
#  [-4267.9062  1811.3887]
#  [-4255.2065  1808.669 ]
#  [-4277.2144  1806.7839]
#  [-4236.417   1825.544 ]
#  [-4261.7173  1811.7253]
#  [-4239.4077  1828.5691]
#  [-4263.142   1803.718 ]
#  [-4259.498   1806.0105]
#  [-4274.816   1807.2021]
#  [-4222.2915  1798.7427]
#  [-4246.6943  1822.915 ]
#  [-4241.76    1824.8156]
#  [-4270.9204  1798.8212]
#  [-4242.282   1808.9783]
#  [-4233.755   1805.6368]
#  [-4240.2563  1797.5665]]
# 1784.4644914269447 1825.884490430355
# 1802.7699 1794.3202

# %%
for method in metrics:
    print(f"Results for {method}:")
    for metric in metrics[method]:
        mean_value = np.mean(metrics[method][metric])
        std_value = np.std(metrics[method][metric])
        print(f"  {metric.capitalize()}: Mean = {mean_value:.4f}, Std = {std_value:.4f}")
# Out:
# Results for TissueGANBaseline:
#   Mse: Mean = 1.1995, Std = 0.0652
#   F1: Mean = 0.6739, Std = 0.0091
#   Cosine_sim: Mean = 0.0609, Std = 0.0214
#   Chamfer_dist: Mean = 59.5196, Std = 12.9991
#   Emd: Mean = 54.0886, Std = 8.3394
