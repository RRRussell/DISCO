# %%
# %load_ext autoreload
# %autoreload 2
import tqdm
import numpy as np
import pandas as pd

import torch
from torch.nn.utils import clip_grad_norm_
from torch.utils.data import DataLoader

from data import load_test_data, generate_training_samples
from dataset import STDataset
from evaluate import Evaluator
from utils import *

from parameter import create_args
from baseline import LatentSpaceGAN

# %%
training_samples = generate_training_samples(num_samples_per_slice=10)
all_test_items = load_test_data(num_holes=10)
# Out:
# Seeding all randomness with seed=2024
# Seeding all randomness with seed=2024
# Donor_id: MsBrainAgingSpatialDonor_1
# Slice_id: 0
# Donor_id: MsBrainAgingSpatialDonor_2
# Slice_id: 0
# Slice_id: 1
# Donor_id: MsBrainAgingSpatialDonor_3
# Slice_id: 0
# Slice_id: 1
# Donor_id: MsBrainAgingSpatialDonor_4
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_5
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_6
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_7
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_8
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_9
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_10
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_11
# Slice_id: 0
# Slice_id: 1
# Slice_id: 2
# Donor_id: MsBrainAgingSpatialDonor_12
# Slice_id: 0
# Slice_id: 1

# %%
dataset = STDataset(training_samples)
# dataset = STDataset(filter_training_samples)
# Define a DataLoader to handle batching
# dataloader = DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)
dataloader = DataLoader(dataset, batch_size=100, shuffle=True)

# %%
model = LatentSpaceGAN()
model.train_model(dataloader=dataloader)
# Out:
# Training VAE...
# Epoch 1, Average Loss: 3.6533
# Epoch 2, Average Loss: 2.3188
# Epoch 3, Average Loss: 1.6686
# Epoch 4, Average Loss: 1.4297
# Epoch 5, Average Loss: 1.3457
# Epoch 6, Average Loss: 1.2878
# Epoch 7, Average Loss: 1.2684
# Epoch 8, Average Loss: 1.2250
# Epoch 9, Average Loss: 1.2254
# Epoch 10, Average Loss: 1.2165
# Epoch 11, Average Loss: 1.1724
# Epoch 12, Average Loss: 1.1922
# Epoch 13, Average Loss: 1.1971
# Epoch 14, Average Loss: 1.1964
# Epoch 15, Average Loss: 1.2207
# Epoch 16, Average Loss: 1.1921
# Epoch 17, Average Loss: 1.1939
# Epoch 18, Average Loss: 1.2032
# Epoch 19, Average Loss: 1.1884
# Epoch 20, Average Loss: 1.1883
# Epoch 21, Average Loss: 1.2023
# Epoch 22, Average Loss: 1.1870
# Epoch 23, Average Loss: 1.2146
# Epoch 24, Average Loss: 1.1978
# Epoch 25, Average Loss: 1.1973
# Epoch 26, Average Loss: 1.1938
# Epoch 27, Average Loss: 1.1944
# Epoch 28, Average Loss: 1.1919
# Epoch 29, Average Loss: 1.1888
# Epoch 30, Average Loss: 1.1877
# Epoch 31, Average Loss: 1.1732
# Epoch 32, Average Loss: 1.2069
# Epoch 33, Average Loss: 1.1932
# Epoch 34, Average Loss: 1.1958
# Epoch 35, Average Loss: 1.1686
# Epoch 36, Average Loss: 1.1858
# Epoch 37, Average Loss: 1.1999
# Epoch 38, Average Loss: 1.2097
# Epoch 39, Average Loss: 1.1542
# Epoch 40, Average Loss: 1.2165
# Epoch 41, Average Loss: 1.2246
# Epoch 42, Average Loss: 1.1987
# Epoch 43, Average Loss: 1.1641
# Epoch 44, Average Loss: 1.1802
# Epoch 45, Average Loss: 1.1797
# Epoch 46, Average Loss: 1.1915
# Epoch 47, Average Loss: 1.1920
# Epoch 48, Average Loss: 1.1717
# Epoch 49, Average Loss: 1.1899
# Epoch 50, Average Loss: 1.1905
# Training GAN...
# Epoch 1, D Loss: 1.3932, G Loss: 0.7154
# Epoch 2, D Loss: 1.2765, G Loss: 0.6886
# Epoch 3, D Loss: 1.1899, G Loss: 0.6710
# Epoch 4, D Loss: 1.1385, G Loss: 0.6820
# Epoch 5, D Loss: 1.0800, G Loss: 0.7234
# Epoch 6, D Loss: 1.0259, G Loss: 0.7557
# Epoch 7, D Loss: 0.9979, G Loss: 0.7826
# Epoch 8, D Loss: 0.9596, G Loss: 0.8110
# Epoch 9, D Loss: 0.9464, G Loss: 0.8220
# Epoch 10, D Loss: 0.9299, G Loss: 0.8394
# Epoch 11, D Loss: 0.9208, G Loss: 0.8418
# Epoch 12, D Loss: 0.9145, G Loss: 0.8493
# Epoch 13, D Loss: 0.9114, G Loss: 0.8527
# Epoch 14, D Loss: 0.9092, G Loss: 0.8512
# Epoch 15, D Loss: 0.8995, G Loss: 0.8605
# Epoch 16, D Loss: 0.8991, G Loss: 0.8612
# Epoch 17, D Loss: 0.8975, G Loss: 0.8580
# Epoch 18, D Loss: 0.8981, G Loss: 0.8636
# Epoch 19, D Loss: 0.8967, G Loss: 0.8641
# Epoch 20, D Loss: 0.8926, G Loss: 0.8648
# Epoch 21, D Loss: 0.8975, G Loss: 0.8605
# Epoch 22, D Loss: 0.9004, G Loss: 0.8571
# Epoch 23, D Loss: 0.8956, G Loss: 0.8620
# Epoch 24, D Loss: 0.8975, G Loss: 0.8614
# Epoch 25, D Loss: 0.8989, G Loss: 0.8608
# Epoch 26, D Loss: 0.8949, G Loss: 0.8598
# Epoch 27, D Loss: 0.8938, G Loss: 0.8691
# Epoch 28, D Loss: 0.8954, G Loss: 0.8620
# Epoch 29, D Loss: 0.8941, G Loss: 0.8595
# Epoch 30, D Loss: 0.8949, G Loss: 0.8613
# Epoch 31, D Loss: 0.8974, G Loss: 0.8575
# Epoch 32, D Loss: 0.8922, G Loss: 0.8622
# Epoch 33, D Loss: 0.8937, G Loss: 0.8593
# Epoch 34, D Loss: 0.8928, G Loss: 0.8633
# Epoch 35, D Loss: 0.8937, G Loss: 0.8606
# Epoch 36, D Loss: 0.8950, G Loss: 0.8627
# Epoch 37, D Loss: 0.8904, G Loss: 0.8605
# Epoch 38, D Loss: 0.8971, G Loss: 0.8582
# Epoch 39, D Loss: 0.8966, G Loss: 0.8613
# Epoch 40, D Loss: 0.8932, G Loss: 0.8632
# Epoch 41, D Loss: 0.8973, G Loss: 0.8578
# Epoch 42, D Loss: 0.8938, G Loss: 0.8640
# Epoch 43, D Loss: 0.8965, G Loss: 0.8604
# Epoch 44, D Loss: 0.8956, G Loss: 0.8641
# Epoch 45, D Loss: 0.8924, G Loss: 0.8647
# Epoch 46, D Loss: 0.8922, G Loss: 0.8664
# Epoch 47, D Loss: 0.9008, G Loss: 0.8573
# Epoch 48, D Loss: 0.8914, G Loss: 0.8650
# Epoch 49, D Loss: 0.9001, G Loss: 0.8589
# Epoch 50, D Loss: 0.8876, G Loss: 0.8660

# %%
# Initialize dictionaries to store metrics
metrics = {
    'L-GANBaseline': {
        'mse': [],
        'f1': [],
        'cosine_sim': [],
        'chamfer_dist': [],
        'emd': []
    }
}

# %%
for i, test_item in enumerate(all_test_items):
    print(f"Test Area {i+1}:")
    print(f"  Dominant Tissue: {test_item.test_area.dominant_tissue}")
    print(f"  Number of cells in ground truth: {len(test_item.ground_truth.hole_cells)}")

    # Evaluate the predicted results
    true_coords = test_item.ground_truth.hole_cells[['center_x', 'center_y']].values
    true_gene_expressions = test_item.ground_truth.gene_expression

    coords, gene_expressions = model.fill_region(adata=test_item.adata, test_area=test_item.test_area)

    mse, f1, cosine_sim = Evaluator.evaluate_expression(true_coords, true_gene_expressions, coords, gene_expressions)
    chamfer_dist = Evaluator.chamfer_distance(true_coords, coords)
    emd = Evaluator.calculate_emd(true_coords, coords)

    # Collect results for KNNBaseline
    metrics['L-GANBaseline']['mse'].append(mse)
    metrics['L-GANBaseline']['f1'].append(f1)
    metrics['L-GANBaseline']['cosine_sim'].append(cosine_sim)
    metrics['L-GANBaseline']['chamfer_dist'].append(chamfer_dist)
    metrics['L-GANBaseline']['emd'].append(emd)
# Out:
# Test Area 1:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 2:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 3:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 4:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 5:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 6:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 7:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 8:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 9:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 10:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 11:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 12:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 13:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 14:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 15:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 16:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 17:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 18:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 19:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 20:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 21:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 22:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 23:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 24:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 25:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 26:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 27:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 28:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 29:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 30:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 31:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 32:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 33:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 34:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 35:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 36:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 37:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 38:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 39:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 40:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 41:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 42:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 43:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 44:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 45:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 46:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 47:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 48:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 49:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 50:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 51:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 52:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 53:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 54:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 55:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 56:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 57:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 58:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 59:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 60:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 61:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 62:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 63:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 64:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 65:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 66:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 67:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 68:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 69:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 70:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 71:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 72:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 73:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 74:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 75:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 76:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 77:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 78:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 79:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 80:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 81:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 82:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 83:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 84:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 85:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 86:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 87:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 88:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 89:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 90:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 91:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 92:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 93:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 94:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 95:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 96:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 97:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 98:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 99:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 100:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 101:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 102:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 103:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 104:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 105:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 106:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 107:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 108:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 109:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 110:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 111:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 112:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 113:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 114:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 115:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 116:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 117:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 118:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 119:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 120:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 121:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 122:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 123:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 124:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 125:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 126:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 127:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 128:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 129:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 130:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 131:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 132:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 133:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 134:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 135:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 136:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 137:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 138:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 139:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 140:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 141:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 142:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 143:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 144:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 145:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 146:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 147:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 148:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 149:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 150:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 151:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 152:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 153:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 154:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 155:
#   Dominant Tissue: pia mater
#   Number of cells in ground truth: 50
# Test Area 156:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 157:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 158:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 159:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 160:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 161:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 162:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 163:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 164:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 165:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 166:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 167:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 168:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 169:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 170:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 171:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 172:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 173:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 174:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 175:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 176:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 177:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 178:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 179:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 180:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 181:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 182:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 183:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 184:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 185:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 186:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 187:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 188:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 189:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 190:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 191:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 192:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 193:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 194:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 195:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 196:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 197:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 198:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 199:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 200:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 201:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 202:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 203:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 204:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 205:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 206:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 207:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 208:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 209:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 210:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 211:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 212:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 213:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 214:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 215:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 216:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 217:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 218:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 219:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 220:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 221:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 222:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 223:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 224:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 225:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 226:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 227:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 228:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 229:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 230:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 231:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 232:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 233:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 234:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 235:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 236:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 237:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 238:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 239:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 240:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 241:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 242:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 243:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 244:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 245:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 246:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 247:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 248:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 249:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 250:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 251:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 252:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 253:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 254:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 255:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 256:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 257:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 258:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 259:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 260:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 261:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 262:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 263:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 264:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 265:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 266:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 267:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 268:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 269:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 270:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 271:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 272:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 273:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 274:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 275:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 276:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 277:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 278:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 279:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 280:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 281:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 282:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 283:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 284:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 285:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 286:
#   Dominant Tissue: corpus callosum
#   Number of cells in ground truth: 50
# Test Area 287:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 288:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 289:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 290:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 291:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 292:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 293:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 294:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 295:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 296:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 297:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 298:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 299:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 300:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 301:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50
# Test Area 302:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 303:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 304:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 305:
#   Dominant Tissue: cortical layer V
#   Number of cells in ground truth: 50
# Test Area 306:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 307:
#   Dominant Tissue: cortical layer II/III
#   Number of cells in ground truth: 50
# Test Area 308:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 309:
#   Dominant Tissue: cortical layer VI
#   Number of cells in ground truth: 50
# Test Area 310:
#   Dominant Tissue: striatum
#   Number of cells in ground truth: 50

# %%
for method in metrics:
    print(f"Results for {method}:")
    for metric in metrics[method]:
        mean_value = np.mean(metrics[method][metric])
        std_value = np.std(metrics[method][metric])
        print(f"  {metric.capitalize()}: Mean = {mean_value:.4f}, Std = {std_value:.4f}")
# Out:
# Results for L-GANBaseline:
#   Mse: Mean = 0.9674, Std = 0.2391
#   F1: Mean = 0.5966, Std = 0.0539
#   Cosine_sim: Mean = 0.0216, Std = 0.0596
#   Chamfer_dist: Mean = 78.6854, Std = 9.5834
#   Emd: Mean = 72.3266, Std = 6.9106
